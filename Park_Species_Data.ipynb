# %%
import pandas as pd
import json

# %%
file = "Resources/species.csv"

# %%
species = pd.read_csv(file)
species.head()
# Out:
# /Users/abayomi/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# ...

# %%
species.drop(species.iloc[:, 9:], inplace=True, axis=1)

# %%
species.drop(columns = ["Species ID"], inplace=True, axis=1)

# %%
species.drop(columns = ["Record Status"], inplace=True, axis=1)

# %%
species.head()
# Out:
#               Park Name Category         Order    Family  \
# 0  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  Acadia National Park   Mammal     Carnivora   Canidae
# 3  Acadia National Park   Mammal     Carnivora   Canidae
# 4  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#       Occurrence
# 0        Present
# 1        Present
# 2        Present
# 3  Not Confirmed
# 4        Present

# %%
species_1 = species["Occurrence"]=="Present"

# %%
present_species = species[species_1]

# %%
present_species.head()
# Out:
#               Park Name Category         Order      Family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora     Canidae
# 8  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 8        Lutra canadensis                                 Otter, River Otter
#
#   Occurrence
# 0    Present
# 1    Present
# 2    Present
# 4    Present
# 8    Present

# %%
animals = present_species["Category"].unique().tolist()
animals_1 = animals[0:4]
animals_1
# Out:
# ['Mammal', 'Bird', 'Reptile', 'Amphibian']

# %%
animal_species = present_species[present_species["Category"].isin(animals_1)]
animal_species.head()
# Out:
#               Park Name Category         Order      Family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora     Canidae
# 8  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 8        Lutra canadensis                                 Otter, River Otter
#
#   Occurrence
# 0    Present
# 1    Present
# 2    Present
# 4    Present
# 8    Present

# %%
animal_species.drop(columns = ["Occurrence"], inplace=True, axis=1)
# Out:
# /Users/abayomi/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
animal_species
# Out:
#                    Park Name   Category         Order          Family  \
# 0       Acadia National Park     Mammal  Artiodactyla        Cervidae
# 1       Acadia National Park     Mammal  Artiodactyla        Cervidae
# 2       Acadia National Park     Mammal     Carnivora         Canidae
# 4       Acadia National Park     Mammal     Carnivora         Canidae
# 8       Acadia National Park     Mammal     Carnivora      Mustelidae
# ...                      ...        ...           ...             ...
# 117865    Zion National Park  Amphibian         Anura       Bufonidae
# 117866    Zion National Park  Amphibian         Anura         Hylidae
# 117867    Zion National Park  Amphibian         Anura         Ranidae
# 117868    Zion National Park  Amphibian         Anura  Scaphiopodidae
# 117869    Zion National Park  Amphibian       Caudata  Ambystomatidae
#
#                Scientific Name  \
# 0                  Alces alces
# 1       Odocoileus virginianus
# ...

# %%
animal_species['Park Name'] = animal_species['Park Name'].replace(['Black Canyon of the Gunnison National Park','Denali National Park and Preserve'
                                                                   ,'Gates Of The Arctic National Park and Preserve','Glacier Bay National Park and Preserve',
                                                                  'Great Sand Dunes National Park and Preserve','Haleakala National Park',
                                                                  'Hawaii Volcanoes National Park','Katmai National Park and Preserve','Lake Clark National Park and Preserve','Redwood National Park',
                                                                  'Sequoia and Kings Canyon National Parks'],['Black Canyon Of The Gunnison National Park','Denali National Park & Preserve',
                                                                  'Gates Of The Arctic National Park & Preserve','Glacier Bay National Park & Preserve',
                                                                  'Great Sand Dunes National Park & Preserve','Haleakalā National Park',
                                                                  "Hawai'i Volcanoes National Park",'Katmai National Park & Preserve',
                                                                  'Lake Clark National Park & Preserve','Redwood National and State Parks','Sequoia & Kings Canyon National Parks'])
# Out:
# /Users/abayomi/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
animal_species
# Out:
#                    Park Name   Category         Order          Family  \
# 0       Acadia National Park     Mammal  Artiodactyla        Cervidae
# 1       Acadia National Park     Mammal  Artiodactyla        Cervidae
# 2       Acadia National Park     Mammal     Carnivora         Canidae
# 4       Acadia National Park     Mammal     Carnivora         Canidae
# 8       Acadia National Park     Mammal     Carnivora      Mustelidae
# ...                      ...        ...           ...             ...
# 117865    Zion National Park  Amphibian         Anura       Bufonidae
# 117866    Zion National Park  Amphibian         Anura         Hylidae
# 117867    Zion National Park  Amphibian         Anura         Ranidae
# 117868    Zion National Park  Amphibian         Anura  Scaphiopodidae
# 117869    Zion National Park  Amphibian       Caudata  Ambystomatidae
#
#                Scientific Name  \
# 0                  Alces alces
# 1       Odocoileus virginianus
# ...

# %%
# species_json = (animal_species.groupby(["Park Name"], as_index=True)
#                 .apply(lambda x: x[["Category", "Order", "Family", "Scientific Name", "Common Names"]].to_dict("r")).reset_index()
#                 .rename(columns={0: "Animals"})
#                 .to_json("Resources/park_species.json", orient="records"))

# %%
animal_species.to_csv("Resources/park_species.csv")

# %%
x = "Resources/park_species.csv"
x_df = pd.read_csv(x)
x_df
# Out:
#        Unnamed: 0             Park Name   Category         Order  \
# 0               0  Acadia National Park     Mammal  Artiodactyla
# 1               1  Acadia National Park     Mammal  Artiodactyla
# 2               2  Acadia National Park     Mammal     Carnivora
# 3               4  Acadia National Park     Mammal     Carnivora
# 4               8  Acadia National Park     Mammal     Carnivora
# ...           ...                   ...        ...           ...
# 16201      117865    Zion National Park  Amphibian         Anura
# 16202      117866    Zion National Park  Amphibian         Anura
# 16203      117867    Zion National Park  Amphibian         Anura
# 16204      117868    Zion National Park  Amphibian         Anura
# 16205      117869    Zion National Park  Amphibian       Caudata
#
#                Family         Scientific Name  \
# 0            Cervidae             Alces alces
# 1            Cervidae  Odocoileus virginianus
# ...

# %%
# Removing Park with incomplete info
x_df_1 = x_df["Park Name"]!="Wrangell - St Elias National Park and Preserve"

# %%
x_df_new = x_df[x_df_1]

# %%
x_df_new
# Out:
#        Unnamed: 0             Park Name   Category         Order  \
# 0               0  Acadia National Park     Mammal  Artiodactyla
# 1               1  Acadia National Park     Mammal  Artiodactyla
# 2               2  Acadia National Park     Mammal     Carnivora
# 3               4  Acadia National Park     Mammal     Carnivora
# 4               8  Acadia National Park     Mammal     Carnivora
# ...           ...                   ...        ...           ...
# 16201      117865    Zion National Park  Amphibian         Anura
# 16202      117866    Zion National Park  Amphibian         Anura
# 16203      117867    Zion National Park  Amphibian         Anura
# 16204      117868    Zion National Park  Amphibian         Anura
# 16205      117869    Zion National Park  Amphibian       Caudata
#
#                Family         Scientific Name  \
# 0            Cervidae             Alces alces
# 1            Cervidae  Odocoileus virginianus
# ...

# %%
x_df_new.reset_index(inplace=True)

# %%
x_df_new.head()
# Out:
#    index  Unnamed: 0             Park Name Category         Order      Family  \
# 0      0           0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1      1           1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2      2           2  Acadia National Park   Mammal     Carnivora     Canidae
# 3      3           4  Acadia National Park   Mammal     Carnivora     Canidae
# 4      4           8  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           Scientific Name                                       Common Names
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter

# %%
x_df_new.drop(columns=["index", "Unnamed: 0"], axis=1, inplace=True)
# Out:
# /Users/abayomi/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
x_df_new.head()
# Out:
#               Park Name Category         Order      Family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 3  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           Scientific Name                                       Common Names
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter

# %%
x_df_new.to_csv("Resources/park_species.csv")

# %%
# species_json = (x_df_new.groupby(["Park Name"], as_index=True)
#                 .apply(lambda x: x[["Category", "Order", "Family", "Scientific Name", "Common Names"]].to_dict("r")).reset_index()
#                 .rename(columns={0: "Animals"})
#                 .to_json("Resources/park_species.json", orient="records"))

# %%
i = "Resources/nps_park_data.csv"

# %%
park_id = pd.read_csv(i)
park_id
# Out:
#                                   park_id  \
# 0    77E0D7F0-1942-494A-ACE2-9004D2BDC59E
# 1    6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 2    E4C7784E-66A0-4D44-87D0-3E072F5FEF43
# 3    1A47416F-DAA3-4137-9F30-14AF86B4E547
# 4    E6E1D22A-7A89-47F8-813C-B611059A8CF9
# ..                                    ...
# 453  D09FF0F8-B16E-4D2B-9C37-03202D6B8176
# 454  4324B2B4-D1A3-497F-8E6B-27171FAE4DB2
# 455  9854D136-AFC0-4966-BB40-FE9323B56A49
# 456  6F550E4D-AE26-4250-A674-397E2DF88092
# 457  41BAB8ED-C95F-447D-9DA1-FCC4E4D808B2
#
#                                              park_name  \
# 0    Abraham Lincoln Birthplace National Historical...
# 1                                 Acadia National Park
# 2                       Adams National Historical Park
# 3                  African American Civil War Memorial
# 4              African Burial Ground National Monument
# ..                                                 ...
# 453  Yorktown Battlefield Part of Colonial National...
# ...

# %%
park_x = x_df_new["Park Name"].unique().tolist()

# %%
print(park_x, len(park_x))
# Out:
# ['Acadia National Park', 'Arches National Park', 'Badlands National Park', 'Big Bend National Park', 'Biscayne National Park', 'Black Canyon Of The Gunnison National Park', 'Bryce Canyon National Park', 'Canyonlands National Park', 'Capitol Reef National Park', 'Carlsbad Caverns National Park', 'Channel Islands National Park', 'Congaree National Park', 'Crater Lake National Park', 'Cuyahoga Valley National Park', 'Denali National Park & Preserve', 'Death Valley National Park', 'Dry Tortugas National Park', 'Everglades National Park', 'Gates Of The Arctic National Park & Preserve', 'Glacier National Park', 'Glacier Bay National Park & Preserve', 'Great Basin National Park', 'Grand Canyon National Park', 'Great Sand Dunes National Park & Preserve', 'Great Smoky Mountains National Park', 'Grand Teton National Park', 'Guadalupe Mountains National Park', 'Haleakalā National Park', "Hawai'i Volcanoes National Park", 'Hot Springs National Park', 'Isle Royale National Park', 'Joshua Tree Na
# ...

# %%
len(park_id["park_name"].unique().tolist())
# Out:
# 458

# %%
xy = park_id[park_id["park_name"].isin(park_x)]
xy
# Out:
#                                   park_id  \
# 1    6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 23   36240051-018E-4915-B6EA-3F1A7F24FBE4
# 28   B170CCF7-7AB9-48FF-950E-31815FD4DBB2
# 34   C9056F71-7162-4208-8AE9-2D0AEFA594FD
# 41   FBF9F793-5114-4B61-A5BA-6F9ADDFDF459
# 42   BDBD573F-97EF-44E7-A579-471679F2C42A
# 51   6B1D053D-714F-46D1-B410-04BE868F14C1
# 60   319E07D8-E176-41F8-98A9-1E3F8099D0AB
# 67   2F05E2B8-CDA3-434E-9C4C-C7DD828CAC3B
# 71   6FDE39B1-AB4A-4C9A-A5CD-4AF67601CD78
# 82   5595FC7A-F218-4439-8D2E-F47449838820
# 99   EEBA7225-7FF5-4B62-B60C-6BBC66351A4E
# 102  7DC1050A-0DDE-4EF9-B777-3C9349BCC4DE
# 107  F4D44F29-3F67-498F-B05B-0783473D2708
# 111  FFC9F9C4-D79D-4CA7-AB0F-7A2AD30061CD
# 113  C0BF2A42-E353-4FAE-B4C4-AA0676B58100
# 117  167A05D1-5793-49E0-89FE-0A1DDFA9A7F4
# 130  5EA02193-276A-4037-B7DB-5765A56935FD
# 167  BC195D18-71C8-4A99-BF8E-10BFAB849679
# 178  3682DBDE-6746-4979-86CC-2358C5B72661
# 179  2B5178C6-2446-488C-AC31-47E3CEBF7159
# ...

# %%
park_names_xy = xy["park_name"].unique().tolist()
print(park_names_xy, len(park_names_xy))
# Out:
# ['Acadia National Park', 'Arches National Park', 'Badlands National Park', 'Big Bend National Park', 'Biscayne National Park', 'Black Canyon Of The Gunnison National Park', 'Bryce Canyon National Park', 'Canyonlands National Park', 'Capitol Reef National Park', 'Carlsbad Caverns National Park', 'Channel Islands National Park', 'Congaree National Park', 'Crater Lake National Park', 'Cuyahoga Valley National Park', 'Death Valley National Park', 'Denali National Park & Preserve', 'Dry Tortugas National Park', 'Everglades National Park', 'Gates Of The Arctic National Park & Preserve', 'Glacier Bay National Park & Preserve', 'Glacier National Park', 'Grand Canyon National Park', 'Grand Teton National Park', 'Great Basin National Park', 'Great Sand Dunes National Park & Preserve', 'Great Smoky Mountains National Park', 'Guadalupe Mountains National Park', "Hawai'i Volcanoes National Park", 'Hot Springs National Park', 'Isle Royale National Park', 'Joshua Tree National Park', 'Katmai Nation
# ...

# %%
# xy

# %%
list_differences = [i for i in park_x if i not in park_names_xy]
list_differences
# Out:
# ['Haleakalā National Park']

# %%
xy_1 = xy["park_name"]!="Haleakalā National Park"
x_df_2 = xy[xy_1]

# %%
len(x_df_2["park_name"].unique().tolist())
# Out:
# 54

# %%
x_df_3 = x_df_new.rename(columns={"Park Name": "park_name"})

# %%
merged_df = pd.merge(x_df_3, x_df_2, on="park_name")

# %%
merged_df.head()
# Out:
#               park_name Category         Order      Family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 3  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter
#
#                                 park_id                            park_url  \
# ...

# %%
new_park_species = merged_df.drop(columns=["park_url", "park_code", "description", 
                                           "latitude", "longitude", "states", "directions_info", 
                                           "directions_url", "weather_info", "designation"])

# %%
new_park_species.head()
# Out:
#               park_name Category         Order      Family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 3  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter
#
#                                 park_id
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# ...

# %%
new_park_species.columns = map(str.lower, new_park_species.columns)

# %%
new_park_species.head()
# Out:
#               park_name category         order      family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 3  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           scientific name                                       common names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter
#
#                                 park_id
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# ...

# %%
# new_park_species.rename(columns={"park name":"park_name"}, inplace=True)

# %%
new_park_species.to_csv("Resources/park_species.csv")

# %%
new_species_json = (new_park_species.groupby(["park_id", "park_name", "category"], as_index=True)
                .apply(lambda x: x[["order", "family", "scientific name", "common names"]].to_dict("r")).reset_index()
                .rename(columns={0: "animals"})
                .to_json("Resources/test_park_species.json", orient="records"))

# %%
park_species = pd.read_csv("Resources/park_species.csv")
park_species

# %%
#Pull Scientific Names into a DF and change column name to be consistent
# with table
sci_name = park_species[['Scientific Name']]
sci_name = sci_name.rename(columns={"Scientific Name": "sci_name"})
sci_name

# %%
#Save resulting DF as CSV
sci_name.to_csv("Resources/sci_name.csv")

# %%
#Read fild into DF, Rename column headers, drop columns, reconfigure column order
new_park_species = pd.read_csv("Resources/AI_species_files_import_test/AI_park_species.csv")
new_park_species = new_park_species.rename(columns={"park_id": "park_id",
                                                    "category": "category_name",
                                                   "family" :"family",
                                                   "order": "order",
                                                   "common_names": "common_names"
})
new_park_species = new_park_species.drop(columns={"Unnamed: 0",
                                                  "park_name",
                                                  "scientific name"})
new_park_species = new_park_species[["park_id",
                                     "category_name",
                                     "family", "order",
                                     "common names"]]
new_park_species

# %%
#Search for any Null values due to error in DB import
new_park_species[new_park_species.isna().any(axis=1)]

# %%
#Fill all null values with "Not Available"
new_park_species.fillna('Not Available', inplace=True)

# %%
#Check for missing values
new_park_species[new_park_species.isna().any(axis=1)]

# %%
#Confirm replacement
new_park_species.iloc[[9439]]

# %%
#confirm non-null count
new_park_species.info()

# %%
#Save resulting file as CSV
new_park_species.to_csv("Resources/new_park_species.csv")

# %%
new_park_species.head()
# Out:
#               park_name category         order      family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 3  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           scientific name                                       common names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter
#
#                                 park_id
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# ...

# %%
sci_name_sample = new_park_species["scientific name"].to_frame()
sci_name_sample.reset_index(inplace=True)
sci_name_sample.rename(columns={"index":"sci_name_id", "scientific name":"sci_name"}, inplace=True)
sci_name_sample
# Out:
#        sci_name_id                sci_name
# 0                0             Alces alces
# 1                1  Odocoileus virginianus
# 2                2           Canis latrans
# 3                3           Vulpes vulpes
# 4                4        Lutra canadensis
# ...            ...                     ...
# 15900        15900         Bufo woodhousii
# 15901        15901         Hyla arenicolor
# 15902        15902            Rana pipiens
# 15903        15903       Spea intermontana
# 15904        15904      Ambystoma tigrinum
#
# [15905 rows x 2 columns]

# %%
sci_name_sample.to_csv("Resources/sci_name_latest.csv")

# %%
sci_id = sci_name_sample["sci_name_id"].tolist()
len(sci_id)
# Out:
# 15905

# %%
new_park_species["sci_name_id"] = sci_id

# %%
new_park_species.head()
# Out:
#               park_name category         order      family  \
# 0  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park   Mammal     Carnivora     Canidae
# 3  Acadia National Park   Mammal     Carnivora     Canidae
# 4  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#           scientific name                                       common names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter
#
#                                 park_id  sci_name_id
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B            0
# ...

# %%
new_park_species_1 = new_park_species.rename(columns={"category":"category_name", 
                                                      "common names": "common_names"})
new_park_species_1.head()
# Out:
#               park_name category_name         order      family  \
# 0  Acadia National Park        Mammal  Artiodactyla    Cervidae
# 1  Acadia National Park        Mammal  Artiodactyla    Cervidae
# 2  Acadia National Park        Mammal     Carnivora     Canidae
# 3  Acadia National Park        Mammal     Carnivora     Canidae
# 4  Acadia National Park        Mammal     Carnivora  Mustelidae
#
#           scientific name                                       common_names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4        Lutra canadensis                                 Otter, River Otter
#
#                                 park_id  sci_name_id
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B            0
# ...

# %%
new_park_species_1 = new_park_species_1[["sci_name_id", "park_id", 
                                         "category_name", "family", 
                                         "order", "common_names", 
                                         "park_name", "scientific name"]]
new_park_species_1.head()
# Out:
#    sci_name_id                               park_id category_name  \
# 0            0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 1            1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 2            2  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 3            3  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 4            4  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
#
#        family         order  \
# 0    Cervidae  Artiodactyla
# 1    Cervidae  Artiodactyla
# 2     Canidae     Carnivora
# 3     Canidae     Carnivora
# 4  Mustelidae     Carnivora
#
#                                         common_names             park_name  \
# 0                                              Moose  Acadia National Park
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...  Acadia National Park
# 2                             Coyote, Eastern Coyote  Acadia National Park
# 3  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...  Acadia National Park
# ...

# %%
new_new = new_park_species_1.drop(["park_name", "scientific name"], axis=1)

# %%
new_new.head()
# Out:
#    sci_name_id                               park_id category_name  \
# 0            0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 1            1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 2            2  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 3            3  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
# 4            4  6DA17C86-088E-4B4D-B862-7C1BD5CF236B        Mammal
#
#        family         order                                       common_names
# 0    Cervidae  Artiodactyla                                              Moose
# 1    Cervidae  Artiodactyla  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2     Canidae     Carnivora                             Coyote, Eastern Coyote
# 3     Canidae     Carnivora  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
# 4  Mustelidae     Carnivora                                 Otter, River Otter

# %%
new_new.to_csv("Resources/park_species_latest.csv")
