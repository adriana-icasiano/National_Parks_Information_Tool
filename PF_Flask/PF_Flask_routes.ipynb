# %%
import pandas as pd
from sqlalchemy import create_engine
# from config import username, password
import json
import requests 
from pprint import pprint
import time
import pandas as pd
from sqlalchemy import create_engine 
from flask import jsonify

# %%
rds_connection_string = f"postgres:Bootcamp@localhost:5432/park_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['park',
#  'webcam_url',
#  'images',
#  'fire',
#  'sci_name',
#  'park_species',
#  'activity',
#  'park_activities',
#  'park_fee',
#  'fees']

# %%
df = pd.read_sql_query('select * from fire', con=engine)
df
# Out:
#        fire_id                               park_id park_agency  \
# 0       238468  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 1       238469  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 2       238470  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 3       238471  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 4       238472  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# ...        ...                                   ...         ...
# 17064  1798689  76F87FF4-4BAD-453E-8013-2DA8924A5D94         NPS
# 17065  1219623  31E84ADD-24C1-400B-9D8B-4588D8DC521C         NPS
# 17066  1649646  7DD7A9E8-E1E9-4759-A764-5FF81FC520ED         NPS
# 17067  1729938  2DC9444C-880F-4738-BA1F-6FB123935A02         NPS
# 17068  1729939  2DC9444C-880F-4738-BA1F-6FB123935A02         NPS
#
#                                  park_name                  fire_name  \
# 0          Denali National Park & Preserve                 MOOSE CRK1
# ...

# %%
df["lat_lon"] = list(zip(df['latitude'], df['longitude']))
df
# Out:
#        fire_id                               park_id park_agency  \
# 0       238468  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 1       238469  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 2       238470  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 3       238471  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# 4       238472  C0BF2A42-E353-4FAE-B4C4-AA0676B58100         NPS
# ...        ...                                   ...         ...
# 17064  1798689  76F87FF4-4BAD-453E-8013-2DA8924A5D94         NPS
# 17065  1219623  31E84ADD-24C1-400B-9D8B-4588D8DC521C         NPS
# 17066  1649646  7DD7A9E8-E1E9-4759-A764-5FF81FC520ED         NPS
# 17067  1729938  2DC9444C-880F-4738-BA1F-6FB123935A02         NPS
# 17068  1729939  2DC9444C-880F-4738-BA1F-6FB123935A02         NPS
#
#                                  park_name                  fire_name  \
# 0          Denali National Park & Preserve                 MOOSE CRK1
# ...

# %%
lat_lon = df['lat_lon'].to_list()

# %%
lat_lon
# Out:
# [(63.6828, -151.0856),
#  (63.9162, -150.119),
#  (63.5242, -150.9612),
#  (63.7359, -148.914),
#  (63.7162, -148.9023),
#  (63.8517, -150.3543),
#  (62.6542, -150.3539),
#  (63.7143, -148.8276),
#  (63.7304, -149.319),
#  (63.5347, -152.1973),
#  (63.7408, -148.91533),
#  (63.7357, -148.8823),
#  (63.5911, -152.6757),
#  (63.7433, -148.9172),
#  (63.75, -150.1831),
#  (63.8, -150.0667),
#  (63.49717, -152.184183),
#  (58.4338, -135.4865),
#  (58.4172, -135.7696),
#  (58.0993, -154.5355),
#  (58.666, -155.4521),
#  (58.6154, -155.5599),
#  (58.6423, -156.448),
#  (59.1929, -155.1896),
#  (59.1826, -155.0355),
#  (58.9993, -153.6021),
#  (58.9664, -155.1122),
#  (60.6327, -153.9023),
#  (60.0277, -152.6213),
#  (60.3327, -153.9522),
#  (61.0222, -154.3025),
#  (61.08, -154.92),
#  (32.02005, -109.35394),
#  (31.98374, -109.37946),
#  (32.15155, -109.46814),
#  (32.00299, -109.36915),
#  (32.02903, -109.46497),
#  (32.02714, -109.37562),
#  (32.07548, -109.51574),
# ...

# %%
jsonify(lat_lon)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-0634f58976fd> in <module>
# ----> 1 jsonify(lat_lon)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/flask/json/__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/werkzeug/local.py in __getattr__(self, name)
#     345         if name == "__members__":
#     346             return dir(self._get_current_object())
# --> 347         return getattr(self._get_current_object(), name)
#     348
#     349     def __setitem__(self, key, value):
#
# ...

# %%
df = pd.read_sql(""" SELECT PetalLengthCm, Species FROM Iris; """, engine)

# %%
df.head()
# Out:
#    PetalLengthCm      Species
# 0            1.4  Iris-setosa
# 1            1.4  Iris-setosa
# 2            1.3  Iris-setosa
# 3            1.5  Iris-setosa
# 4            1.4  Iris-setosa

# %%
petal_lengths = df.PetalLengthCm.to_list()

# %%
jsonify(petal_lengths)
